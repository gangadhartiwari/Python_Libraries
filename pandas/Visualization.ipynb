# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

#print the graph in the notebook 

# set seaborn style to white 
sns.set_style("white")

# %% [markdown]
# ### Step 2. Import the dataset

# %%
pd.read_csv("C:/Python_pandas/tips.csv")
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("C:/Python_pandas/tips.csv")

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tbill = sns.distplot(tips.total_bill, color = "green",kde = False)

#set labels and titles
tbill.set(xlabel = 'Value', ylabel = 'Frequency', title = 'Total Bill')

# take out the right and upper borders
sns.despine()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3684\1894720914.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   tbill = sns.distplot(tips.total_bill, color = "green",kde = False)

# %%
tbill
# Out:
# <Axes: title={'center': 'Total Bill'}, xlabel='Value', ylabel='Frequency'>

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
# sns.scatterplot(x = "total_bill", y = "tip", data=tips)
sns.jointplot(x = "total_bill", y = "tip", data=tips)
plt.show()

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips)
plt.show()

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
# sns.boxplot(x='day', y = 'total_bill', data=tips)
# plt.show()

sns.stripplot(x = 'day', y='total_bill', data=tips, hue = 'day')
plt.show()

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.scatterplot(x = "tip", y = "day", data=tips, hue='sex')
plt.show()

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x='day', y='total_bill', hue='time', data=tips)
plt.show()

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
sns.set(style = 'ticks')
a = sns.FacetGrid(tips, col='time')
a.map(plt.hist,"tip")
plt.show()

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g = sns.FacetGrid(tips, col = "sex", hue = "smoker")
g.map(plt.scatter, "total_bill", "tip")

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.

# %%
total_avg = tips.groupby('day').agg({"total_bill": "mean"})
total_avg
# Out:
#       total_bill
# day
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000
# Thur   17.682742

# %%
students = ['Adarsh', "madhu", "ashish", "eva"]
marks = [80, 45, 69, 78]

# %%
plt.plot(students, marks, marker ='o')
plt.title("Students Marks - line plot")
plt.xlabel('Students')
plt.ylabel('Marks')
plt.grid(True)
plt.show()

# %%
sns.barplot(x = "day", y = "total_bill", data=total_avg, hue='day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
total_avg1 = tips.groupby("day")['total_bill'].mean()

plt.bar(total_avg1.index, total_avg1.values, color = "skyblue")
plt.title("bar plot")
plt.xlabel("day")
plt.ylabel("total_bill")
plt.show()
